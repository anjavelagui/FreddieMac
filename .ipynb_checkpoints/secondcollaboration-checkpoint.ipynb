# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data_house = pd.read_csv("housing_data_cleaned.csv")

# %%
data_house.head()
# Out:
#    id basements building_code_description category_code_description  \
# 0   1         D         ROW 3 STY MASONRY             Single Family
# 1   2       NaN         ROW 2 STY MASONRY             Single Family
# 2   3         H   ROW B/GAR 2 STY MASONRY             Single Family
# 3   4       NaN         ROW 2 STY MASONRY             Single Family
# 4   5       NaN         ROW 2 STY MASONRY             Single Family
#
#    census_tract central_air  depth  exempt_building  exempt_land  \
# 0           241           N   67.0            49200            0
# 1           201         NaN   70.0                0            0
# 2           281           N   95.5                0            0
# 3           293         NaN  112.5                0            0
# 4            62         NaN   79.0                0            0
#
#    exterior_condition  ...  topography  total_area total_livable_area  \
# 0                   4  ...           F      938.00               1344
# ...

# %%
data_house.describe()
# Out:
#                 id  census_tract          depth  exempt_building  \
# count  68485.00000  68485.000000   68485.000000     6.848500e+04
# mean   34243.00000    191.677871      78.143504     3.976819e+04
# std    19770.06093    112.067828     485.899790     1.156552e+05
# min        1.00000      1.000000       0.000000     0.000000e+00
# 25%    17122.00000     93.000000      55.000000     0.000000e+00
# 50%    34243.00000    188.000000      70.030000     0.000000e+00
# 75%    51364.00000    294.000000      93.250000     4.500000e+04
# max    68485.00000    809.000000  120883.000000     4.895100e+06
#
#          exempt_land  exterior_condition    fireplaces     frontage  \
# count   68485.000000        68485.000000  68485.000000  68485.00000
# mean      131.613244            3.621421      0.048390     19.05056
# std      1755.007476            1.084748      0.278706     87.45497
# min         0.000000            0.000000      0.000000      0.00000
# ...

# %%
data_house['number_of_bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %% [markdown]
# # Modeling

# %%
#Checking Null values
data_house.isna().any()
# Out:
# id                           False
# basements                     True
# building_code_description    False
# category_code_description    False
# census_tract                 False
# central_air                   True
# depth                        False
# exempt_building              False
# exempt_land                  False
# exterior_condition           False
# fireplaces                   False
# frontage                     False
# fuel                          True
# garage_spaces                False
# garage_type                   True
# geographic_ward              False
# interior_condition            True
# location                     False
# market_value                 False
# market_value_date             True
# number_of_bathrooms          False
# number_of_bedrooms           False
# number_of_rooms              False
# number_stories               False
# quality_grade                 True
# sale_date                    False
# sale_price                   False
# ...

# %%
#Checking how many null values
data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-93c38dd31311> in <module>
#       1 #Checking how many null values
# ----> 2 data.isna().sum()
#
# NameError: name 'data' is not defined

# %%
data_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68485 entries, 0 to 68484
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         68485 non-null  int64
#  1   basements                  52431 non-null  object
#  2   building_code_description  68485 non-null  object
#  3   category_code_description  68485 non-null  object
#  4   census_tract               68485 non-null  int64
#  5   central_air                46946 non-null  object
#  6   depth                      68485 non-null  float64
#  7   exempt_building            68485 non-null  int64
#  8   exempt_land                68485 non-null  int64
#  9   exterior_condition         68485 non-null  int64
#  10  fireplaces                 68485 non-null  int64
#  11  frontage                   68485 non-null  float64
#  12  fuel                       3523 non-null   object
# ...

# %%
x = data_house["sale_price"]
y = data_house['year_built']
linereg = sm.OLS(y,x).fit()
linereg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             year_built   R-squared (uncentered):                   0.259
# Model:                            OLS   Adj. R-squared (uncentered):              0.259
# Method:                 Least Squares   F-statistic:                          2.398e+04
# Date:                Mon, 23 Aug 2021   Prob (F-statistic):                        0.00
# Time:                        22:10:45   Log-Likelihood:                     -6.0525e+05
# No. Observations:               68485   AIC:                                  1.211e+06
# Df Residuals:                   68484   BIC:                                  1.211e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#checking residuals
plt.figure(figsize=(10,10))
sns.residplot(x, y, data = data_house, color='b')
plt.title('House Age vs Sale Price', fontsize=15)
plt.xlabel('Year Built', fontsize=15)
plt.ylabel('Sale Price', fontsize=15)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.show()
# Out:
# C:\Users\anjav\Anaconda3\envs\PythonAdv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#using multiliner regression
data_house_features = pd.DataFrame(data=data_house, columns = None)
data_house_features = data_house.drop(['sale_date', 'sale_price', 'year_built', 'zip_code', 'total_area', 'total_livable_area', 'number_stories', 'number_of_rooms', 'number_of_bedrooms', 'number_of_bathrooms', 'garage_spaces'], axis=1)
X= data_house_features
y= data_house['sale_price']
#Adding constant
X_int =sm.add_constant(X)
linereg =sm.OLS(y.astype(float),X_int.astype(float)).fit()
linereg.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-0f2720450930> in <module>
#       6 #Adding constant
#       7 X_int =sm.add_constant(X)
# ----> 8 linereg =sm.OLS(y.astype(float),X_int.astype(float)).fit()
#       9 linereg.summary()
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...

# %%
labels = data['sale_price']
conv_dates = [1 if values == ['year_built'] else 0 for values in data.sale_date]
data['sale_date'] = conv_dates
train1 =data.drop(['id', 'sale_price'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size =0.10, random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ae4bf08b45bb> in <module>
# ----> 1 reg.fit(x_train,y_train)
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
