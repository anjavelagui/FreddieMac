# %%
#Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\anjav\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
#URL of page to be scraped
url = 'http://www.freddiemac.com/pmms/'
browser.visit(url)

# %%
#Scrape page into bs
html = browser.html
soup =bs(html, "html.parser")

# %%
#Create a BeautifulSoup object; parse with 'html.parser'
#soup = BeautifulSoup(response.text, 'html5lib')

# %%
#Get interest rate 
interest_rate = soup.find('div', class_='mortgage-rate-widget__rate_value')

# %%
#Examine the results, then determine element that contains interest rates
print(soup.prettify())
# Out:
# <html class="" data-whatinput="initial" data-whatintent="initial" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Mortgage Rates - Freddie Mac
#   </title>
#   <meta content="Mortgage Rates - Freddie Mac" property="og:title"/>
#   <meta content="Mortgage Rates - Freddie Mac" name="twitter:title"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="http://www.freddiemac.com/pmms/index.html" property="og:url"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
print(interest_rate)
# Out:
# None

# %%
# Now grab the informtion that is need
interest_rate = soup.find_all('div', class_='mortgage-rate-widget__rate')

# %%
#examining the result to determine the information to use
for interest in interest_rate:
    print(interest.find('div', class_='mortgage-rate-widget__rate-title'))
    try:
        #identifing types of interest rates
        title = result.find('div', class_='mortgage-rate-widget__rate-title').text
        rate = result.find('div', class_='mortgage-rate-widget__rate-value')
          
        if (title and rate):
            print(title)
            print(rate)
            
    except:
        print("Nothing found")
# Out:
# <div class="mortgage-rate-widget__rate-title" style="color:#00A5E5">30-Yr FRM</div>
# Nothing found
# <div class="mortgage-rate-widget__rate-title" style="color:#87BE3C">15-Yr FRM</div>
# Nothing found
# <div class="mortgage-rate-widget__rate-title" style="color:#DB691E">5/1-Yr ARM</div>
# Nothing found

# %%
print(soup.find('div', class_='mortgage-rate-widget__rate-value'))
# Out:
# <div class="mortgage-rate-widget__rate-value">2.86%</div>

# %% [markdown]
# browser.quit()
